# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
from transformers import BertTokenizer

# %%
DATA_IN_PATH = './data_in/'

# %%
train_data = pd.read_csv(DATA_IN_PATH + "multinli.train.ko.tsv", sep='\t', error_bad_lines=False)
train_data.head(10)
# Out:
# b'Skipping line 24426: expected 3 fields, saw 4\nSkipping line 156343: expected 3 fields, saw 4\nSkipping line 218766: expected 3 fields, saw 4\nSkipping line 232318: expected 3 fields, saw 4\nSkipping line 253493: expected 3 fields, saw 4\n'
# b'Skipping line 265734: expected 3 fields, saw 4\nSkipping line 282588: expected 3 fields, saw 4\nSkipping line 350969: expected 3 fields, saw 4\n'
#                                            sentence1  \
# 0         개념적으로 크림 스키밍은 제품과 지리라는 두 가지 기본 차원을 가지고 있다.
# 1  시즌 중에 알고 있는 거 알아? 네 레벨에서 다음 레벨로 잃어버리는 거야 브레이브스...
# 2                  우리 번호 중 하나가 당신의 지시를 세밀하게 수행할 것이다.
# 3                       어떻게 아세요? 이 모든 것이 다시 그들의 정보다.
# 4  그래, 만약 네가 테니스화 몇 개를 사러 간다면, 나는 왜 그들이 100달러대에서 ...
# 5            내 워커가 고장나서 지금 화가 났어. 스테레오를 정말 크게 틀어야 해.
# 6  그러나 apse 위에서 살아남은 기독교 모자이크 몇 개는 아기 예수와 함께 성모인데...
# 7                   (슬레이트에 대한 읽기는 잭슨의 연구 결과를 받아들인다.)
# 8                                        게이들과 레즈비언들.
# 9  Rue des Francs-Bourgeois의 끝에는 많은 사람들이 돌과 붉은 벽돌...
#
#                                      sentence2     gold_label
# 0                  제품과 지리학은 크림 스키밍을 작동시키는 것이다.        neutral
# 1                   사람들이 기억하면 다음 수준으로 물건을 잃는다.     entailment
# 2         우리 팀의 일원이 당신의 명령을 엄청나게 정확하게 실행할 것이다.     entailment
# 3                               이 정보는 그들의 것이다.     entailment
# 4                              테니스화의 가격은 다양하다.        neutral
# 5  나는 내 워크맨이 고장나서 화가 나서 이제 스테레오를 정말 크게 틀어야 한다.     entailment
# 6             기독교 모자이크의 대부분은 이슬람교도들에 의해 파괴되었다.        neutral
# 7                슬레이트는 잭슨의 발견에 대해 의견을 가지고 있었다.     entailment
# 8                                        이성애자.  contradiction
# 9       Place des Vosges는 전적으로 회색 대리석으로 만들어졌다.  contradiction

# %%
print('전체 학습데이터의 개수: {}'.format(len(train_data)))
# Out:
# 전체 학습데이터의 개수: 385494

# %%
train_set = pd.Series(train_data['sentence1'].tolist() + train_data['sentence2'].tolist()).astype(str)
train_set.head()
# Out:
# 0           개념적으로 크림 스키밍은 제품과 지리라는 두 가지 기본 차원을 가지고 있다.
# 1    시즌 중에 알고 있는 거 알아? 네 레벨에서 다음 레벨로 잃어버리는 거야 브레이브스...
# 2                    우리 번호 중 하나가 당신의 지시를 세밀하게 수행할 것이다.
# 3                         어떻게 아세요? 이 모든 것이 다시 그들의 정보다.
# 4    그래, 만약 네가 테니스화 몇 개를 사러 간다면, 나는 왜 그들이 100달러대에서 ...
# dtype: object

# %%
print('교육 데이터의 총 질문 수: {}'.format(len(np.unique(train_set))))
print('반복해서 나타나는 질문의 수: {}'.format(np.sum(train_set.value_counts() > 1)))
# Out:
# 교육 데이터의 총 질문 수: 509352
# 반복해서 나타나는 질문의 수: 129078

# %%
# 그래프에 대한 이미지 사이즈 선언
# figsize: (가로, 세로) 형태의 튜플로 입력
plt.figure(figsize=(12, 5))
# 히스토그램 선언
# bins: 히스토그램 값들에 대한 버켓 범위
# range: x축 값의 범위
# alpha: 그래프 색상 투명도
# color: 그래프 색상
# label: 그래프에 대한 라벨
plt.hist(train_set.value_counts(), bins=50, alpha=0.5, color= 'r', label='word')
plt.yscale('log', nonposy='clip')
# 그래프 제목
plt.title('Log-Histogram of question appearance counts')
# 그래프 x 축 라벨
plt.xlabel('Number of occurrences of question')
# 그래프 y 축 라벨
plt.ylabel('Number of questions')
# Out:
# Text(0, 0.5, 'Number of questions')

# %%
print('중복 최대 개수: {}'.format(np.max(train_set.value_counts())))
print('중복 최소 개수: {}'.format(np.min(train_set.value_counts())))
print('중복 평균 개수: {:.2f}'.format(np.mean(train_set.value_counts())))
print('중복 표준편차: {:.2f}'.format(np.std(train_set.value_counts())))
print('중복 중간길이: {}'.format(np.median(train_set.value_counts())))
# 사분위의 대한 경우는 0~100 스케일로 되어있음
print('제 1 사분위 중복: {}'.format(np.percentile(train_set.value_counts(), 25)))
print('제 3 사분위 중복: {}'.format(np.percentile(train_set.value_counts(), 75)))
# Out:
# 중복 최대 개수: 40
# 중복 최소 개수: 1
# 중복 평균 개수: 1.51
# 중복 표준편차: 0.95
# 중복 중간길이: 1.0
# 제 1 사분위 중복: 1.0
# 제 3 사분위 중복: 2.0

# %%
plt.figure(figsize=(12, 5))
# 박스플롯 생성
# 첫번째 파라메터: 여러 분포에 대한 데이터 리스트를 입력
# labels: 입력한 데이터에 대한 라벨
# showmeans: 평균값을 마크함

plt.boxplot([train_set.value_counts()],
             labels=['counts'],
             showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x133fb0950>,
#   <matplotlib.lines.Line2D at 0x133fa7a90>],
#  'caps': [<matplotlib.lines.Line2D at 0x133fa7f90>,
#   <matplotlib.lines.Line2D at 0x133fda4d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x133fb0910>],
#  'medians': [<matplotlib.lines.Line2D at 0x133fdaa10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x133ea1410>],
#  'means': [<matplotlib.lines.Line2D at 0x133fdaf10>]}

# %%
train_length = train_set.apply(len)

# %%
plt.figure(figsize=(15, 10))
plt.hist(train_length, bins=200, range=[0,200], facecolor='r', density=True, label='train')
plt.title("Normalised histogram of character count in questions", fontsize=15)
plt.legend()
plt.xlabel('Number of characters', fontsize=15)
plt.ylabel('Probability', fontsize=15)
# Out:
# Text(0, 0.5, 'Probability')

# %%
print('질문 길이 최대 값: {}'.format(np.max(train_length)))
print('질문 길이 평균 값: {:.2f}'.format(np.mean(train_length)))
print('질문 길이 표준편차: {:.2f}'.format(np.std(train_length)))
print('질문 길이 중간 값: {}'.format(np.median(train_length)))
print('질문 길이 제 1 사분위: {}'.format(np.percentile(train_length, 25)))
print('질문 길이 제 3 사분위: {}'.format(np.percentile(train_length, 75)))
# Out:
# 질문 길이 최대 값: 16542
# 질문 길이 평균 값: 42.33
# 질문 길이 표준편차: 71.97
# 질문 길이 중간 값: 32.0
# 질문 길이 제 1 사분위: 22.0
# 질문 길이 제 3 사분위: 52.0

# %%
plt.figure(figsize=(12, 5))

plt.boxplot(train_length,
             labels=['char counts'],
             showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1341cc790>,
#   <matplotlib.lines.Line2D at 0x1341b38d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1341b3dd0>,
#   <matplotlib.lines.Line2D at 0x1341d4110>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1341cc750>],
#  'medians': [<matplotlib.lines.Line2D at 0x1341b9850>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1341d9250>],
#  'means': [<matplotlib.lines.Line2D at 0x1341b9d50>]}

# %%
train_word_counts = train_set.apply(lambda x:len(x.split(' ')))

# %%
plt.figure(figsize=(15, 10))
plt.hist(train_word_counts, bins=50, range=[0, 50], facecolor='r', density=True, label='train')
plt.title('Normalised histogram of word count in questions', fontsize=15)
plt.legend()
plt.xlabel('Number of words', fontsize=15)
plt.ylabel('Prabability', fontsize=15)
# Out:
# Text(0, 0.5, 'Prabability')

# %%
print('질문 단어 개수 최대 값: {}'.format(np.max(train_word_counts)))
print('질문 단어 개수 평균 값: {:.2f}'.format(np.mean(train_word_counts)))
print('질문 단어 개수 표준편차: {:.2f}'.format(np.std(train_word_counts)))
print('질문 단어 개수 중간 값: {}'.format(np.median(train_word_counts)))
print('질문 단어 개수 제 1 사분위: {}'.format(np.percentile(train_word_counts, 25)))
print('질문 단어 개수 제 3 사분위: {}'.format(np.percentile(train_word_counts, 75)))
print('질문 단어 개수 99 퍼센트: {}'.format(np.percentile(train_word_counts, 99)))
# Out:
# 질문 단어 개수 최대 값: 3295
# 질문 단어 개수 평균 값: 10.54
# 질문 단어 개수 표준편차: 14.85
# 질문 단어 개수 중간 값: 8.0
# 질문 단어 개수 제 1 사분위: 6.0
# 질문 단어 개수 제 3 사분위: 13.0
# 질문 단어 개수 99 퍼센트: 37.0

# %%
plt.figure(figsize=(12, 5))

plt.boxplot(train_word_counts,
             labels=['counts'],
             showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x134af6e10>,
#   <matplotlib.lines.Line2D at 0x134b00f90>],
#  'caps': [<matplotlib.lines.Line2D at 0x134b054d0>,
#   <matplotlib.lines.Line2D at 0x134b059d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x134af6dd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x134b05f10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x134b0e910>],
#  'means': [<matplotlib.lines.Line2D at 0x134b0e450>]}

# %%
qmarks = np.mean(train_set.apply(lambda x: '?' in x)) # 물음표가 구두점으로 쓰임
math = np.mean(train_set.apply(lambda x: '[math]' in x)) # []
fullstop = np.mean(train_set.apply(lambda x: '.' in x)) # 마침표
capital_first = np.mean(train_set.apply(lambda x: x[0].isupper())) #  첫번째 대문자
capitals = np.mean(train_set.apply(lambda x: max([y.isupper() for y in x]))) # 대문자가 몇개
numbers = np.mean(train_set.apply(lambda x: max([y.isdigit() for y in x]))) # 숫자가 몇개

# %%
qmarks = np.mean(train_set.apply(lambda x: '?' in x)) # 물음표가 구두점으로 쓰임
math = np.mean(train_set.apply(lambda x: '[math]' in x)) # []
fullstop = np.mean(train_set.apply(lambda x: '.' in x)) # 마침표
capital_first = np.mean(train_set.apply(lambda x: x[0].isupper())) #  첫번째 대문자
capitals = np.mean(train_set.apply(lambda x: max([y.isupper() for y in x]))) # 대문자가 몇개
numbers = np.mean(train_set.apply(lambda x: max([y.isdigit() for y in x]))) # 숫자가 몇개
                  
print('물음표가있는 질문: {:.2f}%'.format(qmarks * 100))
print('수학 태그가있는 질문: {:.2f}%'.format(math * 100))
print('마침표를 포함한 질문: {:.2f}%'.format(fullstop * 100))
print('첫 글자가 대문자 인 질문: {:.2f}%'.format(capital_first * 100))
print('대문자가있는 질문: {:.2f}%'.format(capitals * 100))
print('숫자가있는 질문: {:.2f}%'.format(numbers * 100))
# Out:
# 물음표가있는 질문: 3.98%
# 수학 태그가있는 질문: 0.00%
# 마침표를 포함한 질문: 90.32%
# 첫 글자가 대문자 인 질문: 3.31%
# 대문자가있는 질문: 8.90%
# 숫자가있는 질문: 13.51%

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-uncased')

# %%
train_bert_token_counts = train_set.apply(lambda x:len(tokenizer.tokenize(x)))

# %%
plt.figure(figsize=(15, 10))
plt.hist(train_bert_token_counts, bins=200, range=[0, 200], facecolor='r', density=True, label='train')
plt.title('Normalised histogram of bpe count in questions', fontsize=15)
plt.legend()
plt.xlabel('Number of words', fontsize=15)
plt.ylabel('Prabability', fontsize=15)
# Out:
# Text(0, 0.5, 'Prabability')

# %%
print('질문 bpe 개수 최대 값: {}'.format(np.max(train_bert_token_counts)))
print('질문 bpe 개수 평균 값: {:.2f}'.format(np.mean(train_bert_token_counts)))
print('질문 bpe 개수 표준편차: {:.2f}'.format(np.std(train_bert_token_counts)))
print('질문 bpe 개수 중간 값: {}'.format(np.median(train_bert_token_counts)))
print('질문 bpe 개수 제 1 사분위: {}'.format(np.percentile(train_bert_token_counts, 25)))
print('질문 bpe 개수 제 3 사분위: {}'.format(np.percentile(train_bert_token_counts, 75)))
print('질문 bpe 개수 99 퍼센트: {}'.format(np.percentile(train_bert_token_counts, 99)))
# Out:
# 질문 bpe 개수 최대 값: 11326
# 질문 bpe 개수 평균 값: 32.51
# 질문 bpe 개수 표준편차: 50.24
# 질문 bpe 개수 중간 값: 25.0
# 질문 bpe 개수 제 1 사분위: 17.0
# 질문 bpe 개수 제 3 사분위: 40.0
# 질문 bpe 개수 99 퍼센트: 110.0

# %%
plt.figure(figsize=(12, 5))

plt.boxplot(train_bert_token_counts,
             labels=['counts'],
             showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x134ffdc50>,
#   <matplotlib.lines.Line2D at 0x135001d90>],
#  'caps': [<matplotlib.lines.Line2D at 0x134ff68d0>,
#   <matplotlib.lines.Line2D at 0x1350037d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x134ffdc10>],
#  'medians': [<matplotlib.lines.Line2D at 0x135003d10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x13569d710>],
#  'means': [<matplotlib.lines.Line2D at 0x135001ed0>]}

# %%
from wordcloud import WordCloud
cloud = WordCloud(font_path = DATA_IN_PATH + 'NanumGothic.ttf', width=800, height=600).generate(" ".join(train_set.astype(str)))
plt.figure(figsize=(15, 10))
plt.imshow(cloud)
plt.axis('off')
# Out:
# (-0.5, 799.5, 599.5, -0.5)

# %%
fig, axe = plt.subplots(ncols=1)
fig.set_size_inches(10, 3)
sns.countplot(train_data['gold_label'])
